# %% [markdown]
# torch.utils.data.Dataset을 상속받아 직접 커스텀 데이터셋(Custom Dataset)을 만드는 경우도 있습니다. torch.utils.data.Dataset은 파이토치에서 데이터셋을 제공하는 추상 클래스입니다. Dataset을 상속받아 다음 메소드들을 오버라이드 하여 커스텀 데이터셋을 만들어보겠습니다.

# %%
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
class CustomDataset(torch.utils.data.Dataset): 
  def __init__(self):
  데이터셋의 전처리를 해주는 부분

  def __len__(self):
  데이터셋의 길이. 즉, 총 샘플의 수를 적어주는 부분

  def __getitem__(self, idx): 
  데이터셋에서 특정 1개의 샘플을 가져오는 함수

# %%
# Dataset 상속
class CustomDataset(Dataset): 
  def __init__(self):
    self.x_data = [[73, 80, 75],
                   [93, 88, 93],
                   [89, 91, 90],
                   [96, 98, 100],
                   [73, 66, 70]]
    self.y_data = [[152], [185], [180], [196], [142]]

  # 총 데이터의 개수를 리턴
  def __len__(self): 
    return len(self.x_data)

  # 인덱스를 입력받아 그에 맵핑되는 입출력 데이터를 파이토치의 Tensor 형태로 리턴
  def __getitem__(self, idx): 
    x = torch.FloatTensor(self.x_data[idx])
    y = torch.FloatTensor(self.y_data[idx])
    return x, y

# %%
dataset = CustomDataset()
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

model = torch.nn.Linear(3,1)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-5) 

nb_epochs = 100
for epoch in range(nb_epochs + 1):
  for batch_idx, samples in enumerate(dataloader):
    # print(batch_idx)
    # print(samples)
    x_train, y_train = samples
    # H(x) 계산
    prediction = model(x_train)

    # cost 계산
    cost = F.mse_loss(prediction, y_train)

    # cost로 H(x) 계산
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
        epoch, nb_epochs, batch_idx+1, len(dataloader),
        cost.item()
        ))
# Out:
# Epoch    0/100 Batch 1/3 Cost: 75906.125000
# Epoch    0/100 Batch 2/3 Cost: 9789.119141
# Epoch    0/100 Batch 3/3 Cost: 6660.016602
# Epoch    1/100 Batch 1/3 Cost: 1465.537964
# Epoch    1/100 Batch 2/3 Cost: 724.357727
# Epoch    1/100 Batch 3/3 Cost: 112.455254
# Epoch    2/100 Batch 1/3 Cost: 50.869812
# Epoch    2/100 Batch 2/3 Cost: 25.502253
# Epoch    2/100 Batch 3/3 Cost: 2.335996
# Epoch    3/100 Batch 1/3 Cost: 5.105654
# Epoch    3/100 Batch 2/3 Cost: 1.062824
# Epoch    3/100 Batch 3/3 Cost: 0.564310
# Epoch    4/100 Batch 1/3 Cost: 1.935071
# Epoch    4/100 Batch 2/3 Cost: 0.785208
# Epoch    4/100 Batch 3/3 Cost: 0.442175
# Epoch    5/100 Batch 1/3 Cost: 0.341385
# Epoch    5/100 Batch 2/3 Cost: 0.759523
# Epoch    5/100 Batch 3/3 Cost: 2.322164
# Epoch    6/100 Batch 1/3 Cost: 1.227172
# Epoch    6/100 Batch 2/3 Cost: 1.047268
# Epoch    6/100 Batch 3/3 Cost: 0.084344
# Epoch    7/100 Batch 1/3 Cost: 0.737822
# Epoch    7/100 Batch 2/3 Cost: 2.157916
# Epoch    7/100 Batch 3/3 Cost: 0.300091
# Epoch    8/100 Batch 1/3 Cost: 0.231916
# Epoch    8/100 Batch 2/3 Cost: 0.859351
# Epoch    8/100 Batch 3/3 Cost: 2.173663
# Epoch    9/100 Batch 1/3 Cost: 1.809201
# Epoch    9/100 Batch 2/3 Cost: 0.135432
# Epoch    9/100 Batch 3/3 Cost: 0.743122
# Epoch   10/100 Batch 1/3 Cost: 0.210457
# Epoch   10/100 Batch 2/3 Cost: 0.818117
# Epoch   10/100 Batch 3/3 Cost: 2.254030
# Epoch   11/100 Batch 1/3 Cost: 0.966028
# Epoch   11/100 Batch 2/3 Cost: 0.041613
# Epoch   11/100 Batch 3/3 Cost: 2.681446
# Epoch   12/100 Batch 1/3 Cost: 0.852143
# Epoch   12/100 Batch 2/3 Cost: 1.052290
# Epoch   12/100 Batch 3/3 Cost: 1.662705
# Epoch   13/100 Batch 1/3 Cost: 1.590347
# Epoch   13/100 Batch 2/3 Cost: 0.780835
# Epoch   13/100 Batch 3/3 Cost: 0.384280
# Epoch   14/100 Batch 1/3 Cost: 0.988715
# Epoch   14/100 Batch 2/3 Cost: 0.412048
# Epoch   14/100 Batch 3/3 Cost: 1.884210
# Epoch   15/100 Batch 1/3 Cost: 1.907261
# Epoch   15/100 Batch 2/3 Cost: 0.335466
# Epoch   15/100 Batch 3/3 Cost: 1.375760
# Epoch   16/100 Batch 1/3 Cost: 0.545754
# Epoch   16/100 Batch 2/3 Cost: 0.697852
# Epoch   16/100 Batch 3/3 Cost: 2.377834
# Epoch   17/100 Batch 1/3 Cost: 0.405747
# Epoch   17/100 Batch 2/3 Cost: 1.650014
# Epoch   17/100 Batch 3/3 Cost: 0.130294
# Epoch   18/100 Batch 1/3 Cost: 0.733215
# Epoch   18/100 Batch 2/3 Cost: 1.903280
# Epoch   18/100 Batch 3/3 Cost: 0.699149
# Epoch   19/100 Batch 1/3 Cost: 0.350996
# Epoch   19/100 Batch 2/3 Cost: 0.820919
# Epoch   19/100 Batch 3/3 Cost: 2.619690
# Epoch   20/100 Batch 1/3 Cost: 1.709430
# Epoch   20/100 Batch 2/3 Cost: 0.883572
# Epoch   20/100 Batch 3/3 Cost: 1.084540
# Epoch   21/100 Batch 1/3 Cost: 0.188028
# Epoch   21/100 Batch 2/3 Cost: 1.713458
# Epoch   21/100 Batch 3/3 Cost: 0.407122
# Epoch   22/100 Batch 1/3 Cost: 1.283601
# Epoch   22/100 Batch 2/3 Cost: 0.350479
# Epoch   22/100 Batch 3/3 Cost: 1.679946
# Epoch   23/100 Batch 1/3 Cost: 1.961915
# Epoch   23/100 Batch 2/3 Cost: 0.731040
# Epoch   23/100 Batch 3/3 Cost: 1.167459
# Epoch   24/100 Batch 1/3 Cost: 0.327597
# Epoch   24/100 Batch 2/3 Cost: 0.896245
# Epoch   24/100 Batch 3/3 Cost: 2.469141
# Epoch   25/100 Batch 1/3 Cost: 0.581990
# Epoch   25/100 Batch 2/3 Cost: 1.291583
# Epoch   25/100 Batch 3/3 Cost: 1.882451
# Epoch   26/100 Batch 1/3 Cost: 0.536539
# Epoch   26/100 Batch 2/3 Cost: 1.499656
# Epoch   26/100 Batch 3/3 Cost: 0.649316
# Epoch   27/100 Batch 1/3 Cost: 1.234622
# Epoch   27/100 Batch 2/3 Cost: 0.698347
# Epoch   27/100 Batch 3/3 Cost: 1.702209
# Epoch   28/100 Batch 1/3 Cost: 1.514748
# Epoch   28/100 Batch 2/3 Cost: 0.246616
# Epoch   28/100 Batch 3/3 Cost: 1.766876
# Epoch   29/100 Batch 1/3 Cost: 0.541559
# Epoch   29/100 Batch 2/3 Cost: 0.639697
# Epoch   29/100 Batch 3/3 Cost: 3.002555
# Epoch   30/100 Batch 1/3 Cost: 0.283704
# Epoch   30/100 Batch 2/3 Cost: 1.566239
# Epoch   30/100 Batch 3/3 Cost: 0.681703
# Epoch   31/100 Batch 1/3 Cost: 0.347751
# Epoch   31/100 Batch 2/3 Cost: 1.602974
# Epoch   31/100 Batch 3/3 Cost: 0.160203
# Epoch   32/100 Batch 1/3 Cost: 0.342035
# Epoch   32/100 Batch 2/3 Cost: 1.598044
# Epoch   32/100 Batch 3/3 Cost: 0.164247
# Epoch   33/100 Batch 1/3 Cost: 0.340957
# Epoch   33/100 Batch 2/3 Cost: 1.596676
# Epoch   33/100 Batch 3/3 Cost: 0.165213
# Epoch   34/100 Batch 1/3 Cost: 0.963779
# Epoch   34/100 Batch 2/3 Cost: 1.063119
# Epoch   34/100 Batch 3/3 Cost: 0.207013
# Epoch   35/100 Batch 1/3 Cost: 0.966612
# Epoch   35/100 Batch 2/3 Cost: 0.214868
# Epoch   35/100 Batch 3/3 Cost: 1.982477
# Epoch   36/100 Batch 1/3 Cost: 0.461222
# Epoch   36/100 Batch 2/3 Cost: 1.644803
# Epoch   36/100 Batch 3/3 Cost: 0.300058
# Epoch   37/100 Batch 1/3 Cost: 0.406638
# Epoch   37/100 Batch 2/3 Cost: 1.633237
# Epoch   37/100 Batch 3/3 Cost: 0.137077
# Epoch   38/100 Batch 1/3 Cost: 0.769265
# Epoch   38/100 Batch 2/3 Cost: 0.552615
# Epoch   38/100 Batch 3/3 Cost: 2.086195
# Epoch   39/100 Batch 1/3 Cost: 0.626523
# Epoch   39/100 Batch 2/3 Cost: 0.596347
# Epoch   39/100 Batch 3/3 Cost: 2.553237
# Epoch   40/100 Batch 1/3 Cost: 0.945885
# Epoch   40/100 Batch 2/3 Cost: 1.082667
# Epoch   40/100 Batch 3/3 Cost: 0.464592
# Epoch   41/100 Batch 1/3 Cost: 0.076362
# Epoch   41/100 Batch 2/3 Cost: 1.666922
# Epoch   41/100 Batch 3/3 Cost: 2.321280
# Epoch   42/100 Batch 1/3 Cost: 0.398772
# Epoch   42/100 Batch 2/3 Cost: 0.956752
# Epoch   42/100 Batch 3/3 Cost: 2.019863
# Epoch   43/100 Batch 1/3 Cost: 0.020030
# Epoch   43/100 Batch 2/3 Cost: 1.899523
# Epoch   43/100 Batch 3/3 Cost: 2.221435
# Epoch   44/100 Batch 1/3 Cost: 1.563205
# Epoch   44/100 Batch 2/3 Cost: 1.386949
# Epoch   44/100 Batch 3/3 Cost: 0.205627
# Epoch   45/100 Batch 1/3 Cost: 0.030855
# Epoch   45/100 Batch 2/3 Cost: 1.836125
# Epoch   45/100 Batch 3/3 Cost: 2.240626
# Epoch   46/100 Batch 1/3 Cost: 0.409187
# Epoch   46/100 Batch 2/3 Cost: 0.968619
# Epoch   46/100 Batch 3/3 Cost: 1.996855
# Epoch   47/100 Batch 1/3 Cost: 1.739099
# Epoch   47/100 Batch 2/3 Cost: 1.495235
# Epoch   47/100 Batch 3/3 Cost: 0.042641
# Epoch   48/100 Batch 1/3 Cost: 0.382443
# Epoch   48/100 Batch 2/3 Cost: 0.821176
# Epoch   48/100 Batch 3/3 Cost: 2.863798
# Epoch   49/100 Batch 1/3 Cost: 1.848680
# Epoch   49/100 Batch 2/3 Cost: 0.918539
# Epoch   49/100 Batch 3/3 Cost: 0.151184
# Epoch   50/100 Batch 1/3 Cost: 0.456109
# Epoch   50/100 Batch 2/3 Cost: 1.173076
# Epoch   50/100 Batch 3/3 Cost: 1.999789
# Epoch   51/100 Batch 1/3 Cost: 0.364785
# Epoch   51/100 Batch 2/3 Cost: 1.702761
# Epoch   51/100 Batch 3/3 Cost: 1.863032
# Epoch   52/100 Batch 1/3 Cost: 1.496957
# Epoch   52/100 Batch 2/3 Cost: 0.504339
# Epoch   52/100 Batch 3/3 Cost: 1.648843
# Epoch   53/100 Batch 1/3 Cost: 2.225151
# Epoch   53/100 Batch 2/3 Cost: 0.911136
# Epoch   53/100 Batch 3/3 Cost: 0.588263
# Epoch   54/100 Batch 1/3 Cost: 0.366963
# Epoch   54/100 Batch 2/3 Cost: 1.609965
# Epoch   54/100 Batch 3/3 Cost: 0.325692
# Epoch   55/100 Batch 1/3 Cost: 0.542056
# Epoch   55/100 Batch 2/3 Cost: 1.569552
# Epoch   55/100 Batch 3/3 Cost: 0.275442
# Epoch   56/100 Batch 1/3 Cost: 1.352609
# Epoch   56/100 Batch 2/3 Cost: 1.120342
# Epoch   56/100 Batch 3/3 Cost: 0.929658
# Epoch   57/100 Batch 1/3 Cost: 0.259408
# Epoch   57/100 Batch 2/3 Cost: 0.866853
# Epoch   57/100 Batch 3/3 Cost: 2.040692
# Epoch   58/100 Batch 1/3 Cost: 1.764459
# Epoch   58/100 Batch 2/3 Cost: 0.278588
# Epoch   58/100 Batch 3/3 Cost: 0.295080
# Epoch   59/100 Batch 1/3 Cost: 1.172747
# Epoch   59/100 Batch 2/3 Cost: 0.967130
# Epoch   59/100 Batch 3/3 Cost: 0.728958
# Epoch   60/100 Batch 1/3 Cost: 0.359969
# Epoch   60/100 Batch 2/3 Cost: 1.173095
# Epoch   60/100 Batch 3/3 Cost: 2.504223
# Epoch   61/100 Batch 1/3 Cost: 0.359055
# Epoch   61/100 Batch 2/3 Cost: 0.766445
# Epoch   61/100 Batch 3/3 Cost: 2.649311
# Epoch   62/100 Batch 1/3 Cost: 0.842431
# Epoch   62/100 Batch 2/3 Cost: 0.784547
# Epoch   62/100 Batch 3/3 Cost: 2.729584
# Epoch   63/100 Batch 1/3 Cost: 1.601263
# Epoch   63/100 Batch 2/3 Cost: 0.238366
# Epoch   63/100 Batch 3/3 Cost: 0.372548
# Epoch   64/100 Batch 1/3 Cost: 0.063637
# Epoch   64/100 Batch 2/3 Cost: 1.693808
# Epoch   64/100 Batch 3/3 Cost: 2.252473
# Epoch   65/100 Batch 1/3 Cost: 0.392997
# Epoch   65/100 Batch 2/3 Cost: 0.951829
# Epoch   65/100 Batch 3/3 Cost: 1.967852
# Epoch   66/100 Batch 1/3 Cost: 0.497242
# Epoch   66/100 Batch 2/3 Cost: 2.303976
# Epoch   66/100 Batch 3/3 Cost: 0.551681
# Epoch   67/100 Batch 1/3 Cost: 1.249306
# Epoch   67/100 Batch 2/3 Cost: 0.682451
# Epoch   67/100 Batch 3/3 Cost: 1.621954
# Epoch   68/100 Batch 1/3 Cost: 0.406902
# Epoch   68/100 Batch 2/3 Cost: 2.556746
# Epoch   68/100 Batch 3/3 Cost: 0.495329
# Epoch   69/100 Batch 1/3 Cost: 0.317290
# Epoch   69/100 Batch 2/3 Cost: 0.918616
# Epoch   69/100 Batch 3/3 Cost: 1.943271
# Epoch   70/100 Batch 1/3 Cost: 1.286828
# Epoch   70/100 Batch 2/3 Cost: 0.312501
# Epoch   70/100 Batch 3/3 Cost: 1.662036
# Epoch   71/100 Batch 1/3 Cost: 0.533699
# Epoch   71/100 Batch 2/3 Cost: 0.616325
# Epoch   71/100 Batch 3/3 Cost: 2.964444
# Epoch   72/100 Batch 1/3 Cost: 0.556542
# Epoch   72/100 Batch 2/3 Cost: 1.340347
# Epoch   72/100 Batch 3/3 Cost: 0.541460
# Epoch   73/100 Batch 1/3 Cost: 1.038259
# Epoch   73/100 Batch 2/3 Cost: 0.225150
# Epoch   73/100 Batch 3/3 Cost: 1.847983
# Epoch   74/100 Batch 1/3 Cost: 0.012449
# Epoch   74/100 Batch 2/3 Cost: 1.847102
# Epoch   74/100 Batch 3/3 Cost: 0.547540
# Epoch   75/100 Batch 1/3 Cost: 1.071279
# Epoch   75/100 Batch 2/3 Cost: 0.859421
# Epoch   75/100 Batch 3/3 Cost: 0.311942
# Epoch   76/100 Batch 1/3 Cost: 0.840088
# Epoch   76/100 Batch 2/3 Cost: 1.320229
# Epoch   76/100 Batch 3/3 Cost: 0.657258
# Epoch   77/100 Batch 1/3 Cost: 1.495277
# Epoch   77/100 Batch 2/3 Cost: 0.225782
# Epoch   77/100 Batch 3/3 Cost: 0.488672
# Epoch   78/100 Batch 1/3 Cost: 0.685661
# Epoch   78/100 Batch 2/3 Cost: 2.059303
# Epoch   78/100 Batch 3/3 Cost: 0.348834
# Epoch   79/100 Batch 1/3 Cost: 0.956733
# Epoch   79/100 Batch 2/3 Cost: 0.140332
# Epoch   79/100 Batch 3/3 Cost: 2.264948
# Epoch   80/100 Batch 1/3 Cost: 0.572031
# Epoch   80/100 Batch 2/3 Cost: 0.609753
# Epoch   80/100 Batch 3/3 Cost: 2.430689
# Epoch   81/100 Batch 1/3 Cost: 0.325547
# Epoch   81/100 Batch 2/3 Cost: 1.545786
# Epoch   81/100 Batch 3/3 Cost: 0.343359
# Epoch   82/100 Batch 1/3 Cost: 1.654577
# Epoch   82/100 Batch 2/3 Cost: 0.177476
# Epoch   82/100 Batch 3/3 Cost: 0.668414
# Epoch   83/100 Batch 1/3 Cost: 0.779836
# Epoch   83/100 Batch 2/3 Cost: 1.113312
# Epoch   83/100 Batch 3/3 Cost: 0.200074
# Epoch   84/100 Batch 1/3 Cost: 0.760663
# Epoch   84/100 Batch 2/3 Cost: 1.943855
# Epoch   84/100 Batch 3/3 Cost: 0.370186
# Epoch   85/100 Batch 1/3 Cost: 0.307624
# Epoch   85/100 Batch 2/3 Cost: 0.799018
# Epoch   85/100 Batch 3/3 Cost: 2.090031
# Epoch   86/100 Batch 1/3 Cost: 0.906869
# Epoch   86/100 Batch 2/3 Cost: 0.043638
# Epoch   86/100 Batch 3/3 Cost: 2.610116
# Epoch   87/100 Batch 1/3 Cost: 1.559229
# Epoch   87/100 Batch 2/3 Cost: 0.423156
# Epoch   87/100 Batch 3/3 Cost: 0.309102
# Epoch   88/100 Batch 1/3 Cost: 0.187116
# Epoch   88/100 Batch 2/3 Cost: 0.903756
# Epoch   88/100 Batch 3/3 Cost: 2.160051
# Epoch   89/100 Batch 1/3 Cost: 1.976246
# Epoch   89/100 Batch 2/3 Cost: 0.976593
# Epoch   89/100 Batch 3/3 Cost: 0.590348
# Epoch   90/100 Batch 1/3 Cost: 0.227363
# Epoch   90/100 Batch 2/3 Cost: 1.139226
# Epoch   90/100 Batch 3/3 Cost: 2.315147
# Epoch   91/100 Batch 1/3 Cost: 0.209341
# Epoch   91/100 Batch 2/3 Cost: 2.386973
# Epoch   91/100 Batch 3/3 Cost: 0.199106
# Epoch   92/100 Batch 1/3 Cost: 0.123667
# Epoch   92/100 Batch 2/3 Cost: 1.521956
# Epoch   92/100 Batch 3/3 Cost: 2.264351
# Epoch   93/100 Batch 1/3 Cost: 0.060011
# Epoch   93/100 Batch 2/3 Cost: 0.908726
# Epoch   93/100 Batch 3/3 Cost: 2.388859
# Epoch   94/100 Batch 1/3 Cost: 0.556566
# Epoch   94/100 Batch 2/3 Cost: 1.358428
# Epoch   94/100 Batch 3/3 Cost: 0.561631
# Epoch   95/100 Batch 1/3 Cost: 0.300980
# Epoch   95/100 Batch 2/3 Cost: 1.522856
# Epoch   95/100 Batch 3/3 Cost: 0.355608
# Epoch   96/100 Batch 1/3 Cost: 0.365983
# Epoch   96/100 Batch 2/3 Cost: 0.923128
# Epoch   96/100 Batch 3/3 Cost: 1.930572
# Epoch   97/100 Batch 1/3 Cost: 0.426329
# Epoch   97/100 Batch 2/3 Cost: 1.001384
# Epoch   97/100 Batch 3/3 Cost: 1.807756
# Epoch   98/100 Batch 1/3 Cost: 0.460449
# Epoch   98/100 Batch 2/3 Cost: 0.691320
# Epoch   98/100 Batch 3/3 Cost: 2.935458
# Epoch   99/100 Batch 1/3 Cost: 1.563257
# Epoch   99/100 Batch 2/3 Cost: 0.923662
# Epoch   99/100 Batch 3/3 Cost: 0.969565
# Epoch  100/100 Batch 1/3 Cost: 0.865230
# Epoch  100/100 Batch 2/3 Cost: 0.462816
# Epoch  100/100 Batch 3/3 Cost: 1.930572

# %%
# 임의의 입력 [73, 80, 75]를 선언
new_var =  torch.FloatTensor([[73, 80, 75]]) 
# 입력한 값 [73, 80, 75]에 대해서 예측값 y를 리턴받아서 pred_y에 저장
pred_y = model(new_var) 
print("훈련 후 입력이 73, 80, 75일 때의 예측값 :", pred_y)
# Out:
# 훈련 후 입력이 73, 80, 75일 때의 예측값 : tensor([[151.1182]], grad_fn=<AddmmBackward0>)
